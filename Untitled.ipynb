# %%
# 📦 Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
print(df.columns.tolist())
# Out:
# ['countryCode', 'country', 'pollutantName', 'sectorCode', 'year', 'value', 'unit', 'notation', 'parentSectorCode', 'sectorName']

# %%
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.rename(columns={
    'Country': 'country',
    'Pollutant': 'pollutantName',
    'Sector': 'sectorName',
    'Year': 'year',
    'EmissionValue': 'value'
}, inplace=True)

# %%
print(df.columns.tolist())
# Out:
# ['countryCode', 'country', 'pollutantName', 'sectorCode', 'year', 'value', 'unit', 'notation', 'parentSectorCode', 'sectorName']

# %%
# 📁 Constants
DATA_PATH = 'emissions_data.csv'  # Ensure this file exists in your working directory
COUNTRY = 'Austria'
POLLUTANT = 'As'
SECTOR_KEYWORD = 'manure'
RESTORATION_YEAR = 2025
REDUCTION_FACTOR = 0.7

# 📊 Load Dataset
def load_dataset(path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"❌ Dataset not found at: {path}")
    df = pd.read_csv(path, sep='\t', low_memory=False)
    df.columns = df.columns.str.strip()
    return df

# 🔍 Validate Columns
def validate_columns(df, required_cols):
    missing = [col for col in required_cols if col not in df.columns]
    if missing:
        raise ValueError(f"❌ Missing columns in dataset: {missing}")

# 🔬 Filter Dataset
def filter_emissions(df, country, pollutant, sector):
    print("🔎 Available countries:", df['country'].unique())
    print("🔎 Available pollutants:", df['pollutantName'].unique())
    print("🔎 Available sectors:", df['sectorName'].unique())

    df_filtered = df[
        df['country'].str.contains(country, case=False, na=False) &
        df['pollutantName'].str.lower().str.contains(pollutant.lower(), na=False) &
        df['sectorName'].str.lower().str.contains(sector.lower(), na=False)
    ].copy()

    df_filtered['year'] = pd.to_numeric(df_filtered['year'], errors='coerce')
    df_filtered['value'] = pd.to_numeric(df_filtered['value'], errors='coerce')
    df_filtered = df_filtered.dropna(subset=['year', 'value'])

    return df_filtered

# 📈 Model Restoration Scenario
def model_restoration(df, year_threshold, reduction_factor):
    df_yearly = df.groupby('year')['value'].sum().reset_index()
    df_yearly['restored'] = df_yearly.apply(
        lambda row: row['value'] * reduction_factor if row['year'] >= year_threshold else row['value'],
        axis=1
    )
    return df_yearly

# 📊 Plot Emissions
def plot_emissions(df_yearly, country, pollutant):
    if df_yearly.empty:
        print("⚠️ No data to plot.")
        return

    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_yearly, x='year', y='value', label='Original', marker='o', color='darkred')
    sns.lineplot(data=df_yearly, x='year', y='restored', label='Restoration Scenario', marker='o', color='forestgreen')
    plt.title(f'{pollutant} Emissions from Manure Management in {country} with Restoration Scenario')
    plt.xlabel('Year')
    plt.ylabel('Emissions (kg)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# 🚀 Run Analysis
def run_emissions_analysis():
    df = load_dataset(DATA_PATH)
    validate_columns(df, ['country', 'pollutantName', 'sectorName', 'year', 'value'])

    df_filtered = filter_emissions(df, COUNTRY, POLLUTANT, SECTOR_KEYWORD)
    if df_filtered.empty:
        print("⚠️ No matching data found. Try adjusting filters or inspecting the dataset.")
        return

    df_yearly = model_restoration(df_filtered, RESTORATION_YEAR, REDUCTION_FACTOR)
    plot_emissions(df_yearly, COUNTRY, POLLUTANT)

    print("📊 Grouped emissions data:")
    print(df_yearly)

# 🧠 Execute
if __name__ == "__main__":
    run_emissions_analysis()
# Out:
# 🔎 Available countries: ['Austria' 'Belgium' 'Bulgaria' 'Cyprus' 'Czechia' 'Germany' 'Denmark'
#  'Estonia' 'Spain' 'Finland' 'France' 'Greece' 'Croatia' 'Hungary'
#  'Ireland' 'Italy' 'Lithuania' 'Luxembourg' 'Latvia' 'Malta' 'Netherlands'
#  'Poland' 'Portugal' 'Romania' 'Sweden' 'Slovenia' 'Slovakia'
#  'Switzerland' 'Iceland' 'Liechtenstein' 'Norway' 'Türkiye' 'EEA32' 'EU27']
# 🔎 Available pollutants: ['As' 'BC' 'Benzo(a) Pyrene' 'Benzo(b) Fluoranthene'
#  'benzo(k) Fluoranthene' 'Cd' 'CO' 'Cr' 'Cu' 'HCB' 'Ni' 'NMVOC'
#  'PCDD/PCDF (dioxins/furans)' 'Total PAHs' 'Hg' 'PM10' 'NOx'
#  'Indeno (1,2,3-cd) Pyrene' 'TSP' 'PM2.5' 'Pb' 'Zn' 'NH3' 'Se' 'PCBs'
#  'SOx' 'Biomass' 'Gaseous Fuels' 'Liquid Fuels' 'Other Fuels'
#  'Solid Fuels']
# 🔎 Available sectors: ['Manure management - Non-dairy cattle' 'Manure management - Sheep'
#  'Volcanoes' 'Forest fires'
#  'Other natural emissions (please specify in the IIR)'
#  'Manure management - Swine' 'Manure management - Buffalo'
#  'Public electricity and heat production' 'Manure management - Goats'
#  'Petroleum refining' 'Manure management - Horses'
#  'Manufacture of solid fuels and other energy industries'
#  'Fugitive emissions from natural gas (exploration, production, processing, transmission, storage, distribution and other)'
#  'Manure management - Mules and asses'
#  'Stationary combustion in manufacturing industries and construction: Food processing, beverages and tobacco'
#  'Stationary combustion in manufacturing industries and construction: Iron and steel'
#  'Venting and flaring (oil, gas, combined oil and gas)'
#  'Chemical industry: Other (please specify in the IIR)'
#  'Storage, handling and transport of chemical products (please specify in the IIR)'
#  'Stationary combustion in manufacturing industries and construction: Non-metallic minerals'
#  'Manure management - Laying hens' 'Manure management - Broilers'
#  'Other fugitive emissions from energy production'
#  'Stationary combustion in manufacturing industries and construction: Non-ferrous metals'
#  'Ammonia production'
#  'Mobile combustion in manufacturing industries and construction (please specify in the IIR)'
#  'Municipal waste incineration' 'Industrial waste incineration'
#  'Manure management - Turkeys'
#  'Road transport: Automobile tyre and brake wear' 'Magnesium production'
#  'Lead production' 'Nitric acid production' 'Zinc production'
#  'Hazardous waste incineration'
#  'Stationary combustion in manufacturing industries and construction: Chemicals'
#  'Cement production' 'Lime production'
#  'Stationary combustion in manufacturing industries and construction: Other (please specify in the IIR)'
#  'Manure management - Other poultry' 'Adipic acid production'
#  'Stationary combustion in manufacturing industries and construction: Pulp, Paper and Print'
#  'Glass production' 'International aviation LTO (civil)'
#  'Manure management - Other animals (please specify in the IIR)'
#  'Road transport: Automobile road abrasion' 'Clinical waste incineration'
#  'Carbide production' 'Titanium dioxide production'
#  'Inorganic N-fertilizers (includes also urea application)'
#  'International aviation cruise (civil)' 'Copper production'
#  'Nickel production' 'Sewage sludge incineration'
#  'Quarrying and mining of minerals other than coal'
#  'Animal manure applied to soils' 'Railways'
#  'Domestic aviation LTO (civil)' 'Construction and demolition'
#  'Other metal production (please specify in the IIR)'
#  'Sewage sludge applied to soils' 'International maritime navigation'
#  'International inland waterways' 'Cremation'
#  'Other waste incineration (please specify in the IIR)'
#  'Storage, handling and transport of mineral products'
#  'Soda ash production'
#  'Storage, handling and transport of metal products (please specify in the IIR)'
#  'Other organic fertilisers applied to soils (including compost)'
#  'Domestic aviation cruise (civil)'
#  'Other mineral products (please specify in the IIR)'
#  'Road transport: Passenger cars' 'National navigation (shipping)'
#  'Pipeline transport' 'Other (please specify in the IIR)'
#  'Open burning of waste' 'Domestic wastewater handling'
#  'Industrial wastewater handling' 'Other wastewater handling'
#  'Other waste (please specify in the IIR)'
#  'Other (included in national total for entire territory) (please specify in the IIR)'
#  'Commercial/Institutional: Stationary'
#  'Domestic solvent use including fungicides' 'Road paving with asphalt'
#  'Urine and dung deposited by grazing animals' 'Asphalt roofing'
#  'Crop residues applied to soils' 'Indirect emissions from managed soils'
#  'Iron and steel production' 'Commercial/Institutional: Mobile'
#  'Road transport: Light duty vehicles'
#  'Farm-level agricultural operations including storage, handling and transport of agricultural products'
#  'Residential: Stationary' 'Residential: Household and gardening (mobile)'
#  'Agriculture/Forestry/Fishing: Stationary'
#  'Road transport: Heavy duty vehicles and buses'
#  'Other not included in national total of the entire territory (please specify in the IIR)'
#  'Off-farm storage, handling and transport of bulk agricultural products'
#  'Agriculture/Forestry/Fishing: Off-road vehicles and other machinery'
#  'Agriculture/Forestry/Fishing: National fishing' 'Ferroalloys production'
#  'Road transport: Mopeds & motorcycles' 'Cultivated crops' 'Adjustments'
#  'National total for compliance assessment  (please specify all details in the IIR)'
#  'Coating applications' 'Road transport: Gasoline evaporation'
#  'Aluminium production' 'Use of pesticides'
#  'Field burning of agricultural residues'
#  'Other stationary (including military)'
#  'Agriculture other (please specify in the IIR)' 'Degreasing'
#  'Dry cleaning'
#  'Biological treatment of waste - Solid waste disposal on land'
#  'National total for the entire territory (based on fuel sold)'
#  'Biological treatment of waste - Composting'
#  'Biological treatment of waste - Anaerobic digestion at biogas facilities'
#  'Chemical products'
#  'Other, Mobile (including military, land based and recreational boats)'
#  'Printing' 'Other solvent use (please specify in the IIR)'
#  'Other product use (please specify in the IIR)' 'Pulp and paper industry'
#  'Multilateral operations'
#  'Fugitive emission from solid fuels: Coal mining and handling'
#  'Food and beverages industry'
#  'Fugitive emission from solid fuels: Solid fuel transformation'
#  'Other industrial processes (please specify in the IIR)'
#  'Wood processing' 'Other fugitive emissions from solid fuels'
#  'Production of POPs'
#  'Fugitive emissions oil: Exploration, production, transport'
#  'Consumption of POPs and heavy metals (e.g. electrical and scientific equipment)'
#  'Other production, consumption, storage, transportation or handling of bulk products (please specify in the IIR)'
#  'Fugitive emissions oil: Refining and storage'
#  'Manure management - Dairy cattle' 'Distribution of oil products']
